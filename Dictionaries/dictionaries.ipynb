# %% [markdown]
# # Dictionaries

# %% [markdown]
# * Dictionaries use curly braces and colons to signify the
# keys and their associated values.
#                            {'key1':'value1','key2':'value2'}

# %% [markdown]
# * Objects retrieved by key name.
# Unordered and can not be sorted.

# %%
d1 = {'key1':'value1','key2':'value2'}

# %%
type(d1)
# Out:
# dict

# %%
d1['key2']
# Out:
# 'value2'

# %%
type(d1['key2'])
# Out:
# str

# %%
d2 = {'k1':123,
      'k2':[11,12,13],
      'k3':{'sub_key':'Hello'}}

# %%
d2['k1']
# Out:
# 123

# %%
d2['k2']
# Out:
# [11, 12, 13]

# %%
d2['k2'].append('new item')

# %%
d2['k2']
# Out:
# [11, 12, 13, 'new item']

# %%
d2['k3']
# Out:
# {'sub_key': 'Hello'}

# %%
type(d2['k3'])
# Out:
# dict

# %%
d2['k3']['sub_key']
# Out:
# 'Hello'

# %%
d2['demo_key'] = 'this is a value'

# %%
d2
# Out:
# {'k1': 123,
#  'k2': [11, 12, 13, 'new item'],
#  'k3': {'sub_key': 'Hello'},
#  'demo_key': 'this is a value'}

# %%
d2['k3'] = 'this is a new value'

# %%
d2
# Out:
# {'k1': 123,
#  'k2': [11, 12, 13, 'new item'],
#  'k3': 'this is a new value',
#  'demo_key': 'this is a value'}

# %%
demo_dict = {}

# %%
demo_dict
# Out:
# {}

# %%
demo_dict['a1'] = 'value one'

# %%
demo_dict
# Out:
# {'a1': 'value one'}

# %% [markdown]
# ## Few Dictionary Methods

# %%
d = {'k1':1,'k2':2,'k3':3}

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
d.items() #returns list of tuples of all the k:v pairs
# Out:
# dict_items([('k1', 1), ('k2', 2), ('k3', 3)])
