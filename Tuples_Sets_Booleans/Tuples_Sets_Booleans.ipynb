# %%
t = (1,2,3)

# %%
type(t)
# Out:
# tuple

# %%
t1 = ('one','2', 5.67)

# %%
len(t)
# Out:
# 3

# %%
t.append(67) #because tuple is immutable, we cannot add new element to it.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-c79b842ba3ca> in <cell line: 0>()
# ----> 1 t.append(67)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t[0] = 8 #because tuple is immutable, we cannot change the value of existing element in it.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-cd6f5bf327a2> in <cell line: 0>()
# ----> 1 t[0] = 8
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# ('one', '2', 5.67)

# %%
t1.index(5.67)
# Out:
# 2

# %%
t1.count('one')
# Out:
# 1

# %% [markdown]
# # Sets

# %%
x = set()

# %%
x
# Out:
# set()

# %%
x.add(1)

# %%
x
# Out:
# {1}

# %%
x.add('hi')

# %%
x.add(3)

# %%
x
# Out:
# {1, 3, 'hi'}

# %%
x.add(1)

# %%
x
# Out:
# {1, 3, 'hi'}

# %%
x.add('Hi')

# %%
x
# Out:
# {1, 3, 'Hi', 'hi'}

# %%
l1 = [1,2,3,1,2,1,5,4,6,1,2,3,1,2,5,2,'hi',10,'hello']
l1
# Out:
# [1, 2, 3, 1, 2, 1, 5, 4, 6, 1, 2, 3, 1, 2, 5, 2, 'hi', 10, 'hello']

# %%
set(l1)
# Out:
# {1, 10, 2, 3, 4, 5, 6, 'hello', 'hi'}

# %% [markdown]
# # Booleans

# %%
x = 4 <5

# %%
x
# Out:
# True

# %%
4<7
# Out:
# True

# %%
4/2.3 > 7/2
# Out:
# False

# %% [markdown]
# #Comparison Operators

# %%
#Equal
1 == 1
# Out:
# True

# %%
len('shreyas') == 7
# Out:
# True

# %%
1 == 0
# Out:
# False

# %%
len('shreyas') == 5
# Out:
# False

# %%
#Not Equal
1 != 0
# Out:
# True

# %%
9 != 90/10
# Out:
# False

# %%
#Greater Than or Equal to

3 >= 2
# Out:
# True

# %%
3 >= 3
# Out:
# True

# %%
3 > 3
# Out:
# False

# %%
#Less Than
2 <= 6
# Out:
# True

# %%
2 <= 2
# Out:
# True

# %%
2 < 1
# Out:
# False

# %% [markdown]
# #Chained Comparison (Logical) Operator

# %%
1 < 2 < 3
# Out:
# True

# %%
#and
1<2 and 2<3
# Out:
# True

# %%
1 > 2 and 2 < 3
# Out:
# False

# %%
1<2 and 2 > 3
# Out:
# False

# %%
1>2 and 2>3
# Out:
# False

# %%
#Or
1<2 or 2<3
# Out:
# True

# %%
1<2 or 2>3
# Out:
# True

# %%
1>2 or 2<3
# Out:
# True

# %%
1>2 or 2>3
# Out:
# False
